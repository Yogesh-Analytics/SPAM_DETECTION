# %%
import streamlit as st
import pickle


model = pickle.load(open("model.pkl", "rb"))
vectorizer = pickle.load(open("vectorizer.pkl", "rb"))

st.title("📧 AI Spam Email Detector")

st.write("Paste any email/message below:")

message = st.text_area("Enter Message")

if st.button("Predict"):

 
    data = vectorizer.transform([message])


    result = model.predict(data)[0]

    if result == "spam":
        st.error("🚨 This is SPAM")
    else:
        st.success("✅ This is NOT spam")

    st.write("---")
    st.write("Prediction:", result)
# Out:
# 2026-06-25 15:31:05.885 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-25 15:31:07.284
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Yogesh Fulari\AppData\Roaming\Python\Python313\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-06-25 15:31:07.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-25 15:31:07.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-25 15:31:07.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-25 15:31:07.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-25 15:31:07.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-25 15:31:07.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-25 15:31:07.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-25 15:31:07.293 Session state does not function when running a script without `streamlit run`
# 2026-06-25 15:31:07.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-25 15:31:07.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-25 15:31:07.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-25 15:31:07.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-25 15:31:07.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-25 15:31:07.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-25 15:31:07.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
python -c "open('app.py','w').close()"
# Out:
#   Cell In[2], line 1
#     python -c "open('app.py','w').close()"
#               ^
# SyntaxError: invalid syntax
